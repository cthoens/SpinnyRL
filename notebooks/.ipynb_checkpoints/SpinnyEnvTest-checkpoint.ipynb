# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

import sys
sys.path.append("..")
sys.path.append("../../DolphinRL/Source")

import numpy as np
import asyncio
from SpinnyEnv import SpinnyEnv


import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import logging
import sys
    
root = logging.getLogger()
root.setLevel(logging.INFO)

handler = logging.StreamHandler(sys.stdout)
handler.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
root.addHandler(handler)

# %%
env = SpinnyEnv()
future = asyncio.ensure_future(env.interface.run())
# Out:
# 2021-05-04 20:09:22,911 - root - INFO - Receiving video
# 2021-05-04 20:09:22,950 - aioice.ice - INFO - Connection(0) Check CandidatePair(('fd00::4cc:a465:3b1d:33b', 59287) -> ('fd00::9676:4daa:b08e:16f7', 45632)) State.FROZEN -> State.WAITING
# 2021-05-04 20:09:22,956 - aioice.ice - INFO - Connection(0) Check CandidatePair(('fd00::d039:3f13:ae60:9257', 55900) -> ('fd00::9676:4daa:b08e:16f7', 45632)) State.FROZEN -> State.WAITING
# 2021-05-04 20:09:22,963 - aioice.ice - INFO - Connection(0) Check CandidatePair(('192.168.178.36', 33846) -> ('192.168.178.40', 47239)) State.FROZEN -> State.WAITING
# 2021-05-04 20:09:22,965 - aioice.ice - INFO - Connection(0) Check CandidatePair(('fd00::4cc:a465:3b1d:33b', 59287) -> ('fd00::9676:4daa:b08e:16f7', 45632)) State.WAITING -> State.IN_PROGRESS
# 2021-05-04 20:09:22,985 - aioice.ice - INFO - Connection(0) Check CandidatePair(('fd00::d039:3f13:ae60:9257', 55900) -> ('fd00::9676:4daa:b08e:16f7', 45632)) State.WAITING -> State.IN_PROGRESS
# 2021-05-04 20:09:22,996 - aioice.ice - INFO - Connection(0) Check CandidatePair(('fd00::4cc:a465:3b1d:33b', 59287) -> ('fd00::9676:4daa:b08e:16f7', 45632)) State.IN_PROGRESS -> State.SUCCEEDED
# 2021-05-04 20:09:22,997 - aioice.ice - INFO - Connection(0) Check CandidatePair(('fd00::d039:3f13:ae60:9257', 55900) -> ('fd00::9676:4daa:b08e:16f7', 45632)) State.IN_PROGRESS -> State.SUCCEEDED
# 2021-05-04 20:09:23,007 - aioice.ice - INFO - Connection(0) Check CandidatePair(('192.168.178.36', 33846) -> ('192.168.178.40', 47239)) State.WAITING -> State.IN_PROGRESS
# 2021-05-04 20:09:23,014 - aioice.ice - INFO - Connection(0) Check CandidatePair(('192.168.178.36', 33846) -> ('192.168.178.40', 47239)) State.IN_PROGRESS -> State.SUCCEEDED
# 2021-05-04 20:09:23,027 - aioice.ice - INFO - Connection(0) Check CandidatePair(('192.168.178.36', 33846) -> ('194.191.236.12', 47239)) State.FROZEN -> State.IN_PROGRESS
# 2021-05-04 20:09:23,213 - aioice.ice - INFO - Connection(0) ICE completed
# 2021-05-04 20:09:25,159 - root - INFO - Ice Done
# 2021-05-04 20:09:25,164 - root - INFO - Data channel uv4l created by remote party

# %%
obs = await env.reset()

# %%
obs, reward, done, _ = await env.step(40)

print(reward, done)
imgplot = plt.imshow(obs)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
await env.close()
await future
# Out:
# 2021-05-04 20:09:36,830 - root - INFO - Signalling closed
# 2021-05-04 20:09:36,834 - root - INFO - Peer connection closed

# %%
import cv2

# %%
arucoDict = cv2.aruco.Dictionary_get(cv2.aruco.DICT_6X6_100)
arucoParams = cv2.aruco.DetectorParameters_create()

open_cv_image = np.array(obs.convert('RGB')) 
# Convert RGB to BGR 
open_cv_image = open_cv_image[:, :, ::-1].copy() 


corners, ids, rejected = cv2.aruco.detectMarkers(open_cv_image, arucoDict, parameters=arucoParams)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
obs.save("obs.jpg")

# %%
from PIL import Image, ImageDraw
import random
import math
obs = PIL.Image.open("obs.jpg")

target_angle = 112-190 # random.randrange(0,359)
print(target_angle)
target_angle_rad = target_angle / 360 * (2 * math.pi)  
target_dir = np.array([math.cos(target_angle_rad), math.sin(target_angle_rad)])

marker_id = 75
index = ids.reshape(-1).tolist().index(marker_id)
marker_corners = corners[index][0]

line_from = (marker_corners[0] + marker_corners[1]) * 0.5
line_to = (marker_corners[2] + marker_corners[3]) * 0.5
direction = line_to - line_from
direction = direction / np.linalg.norm(direction)
line_to = line_from + direction * 50
line_to_target = line_from + target_dir * 50

draw = ImageDraw.Draw(obs)
draw.line([*line_from, *line_to], fill=255, width=5)
draw.line([*line_from, *line_to_target], fill=(0, 255, 0), width=5)

actual_angle = math.atan2(direction[1], direction[0])
print(actual_angle / (2 * math.pi)  * 360)

angle_deviation = math.acos(np.dot(direction, target_dir))
print(angle_deviation / (2 * math.pi)  * 360)

#cv2.aruco.drawDetectedMarkers(open_cv_image, [corners[index]])
#open_cv_image = open_cv_image[:, :, ::-1].copy() 
imgplot = plt.imshow(obs)
# Out:
# -78
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-12df2d640939> in <module>
#      10
#      11 marker_id = 75
# ---> 12 index = ids.reshape(-1).tolist().index(marker_id)
#      13 marker_corners = corners[index][0]
#      14
#
# ValueError: 75 is not in list

# %% [markdown]
# ##
